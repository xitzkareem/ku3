# %%
import re 
import pandas as pd

# %% [markdown]
# Essentials for cleaning text and defining pattern functions

# %%
data = '''
ABCDEFGHIJKLMNOPQRSTUVWXYZ
abcdefghijklmnopqrstuvwxyz
123456789
Ha HaHa
3107027121
1231409012
1485929411
Kareem
KUDU
DIJU
'''
sentence = 'Start a sentence  and then bring it to an end'

# %%
## Raw strings : a string pre-fixed with r 
print ('\tTap')
print (r'/tTab')
# Out:
# 	Tap
# /tTab

# %% [markdown]
# Expression and patterns
# re.compile : compile method will allow us to seperate our patterns to variables and make it easier to use the variables to perform multiple searches

# %%
pattern = re.compile (r'\d')
matches = pattern.finditer(data)
 
for match in matches : 
    print (match)
# Out:
# <re.Match object; span=(55, 56), match='1'>
# <re.Match object; span=(56, 57), match='2'>
# <re.Match object; span=(57, 58), match='3'>
# <re.Match object; span=(58, 59), match='4'>
# <re.Match object; span=(59, 60), match='5'>
# <re.Match object; span=(60, 61), match='6'>
# <re.Match object; span=(61, 62), match='7'>
# <re.Match object; span=(62, 63), match='8'>
# <re.Match object; span=(63, 64), match='9'>
# <re.Match object; span=(73, 74), match='3'>
# <re.Match object; span=(74, 75), match='1'>
# <re.Match object; span=(75, 76), match='0'>
# <re.Match object; span=(76, 77), match='7'>
# <re.Match object; span=(77, 78), match='0'>
# <re.Match object; span=(78, 79), match='2'>
# <re.Match object; span=(79, 80), match='7'>
# <re.Match object; span=(80, 81), match='1'>
# <re.Match object; span=(81, 82), match='2'>
# <re.Match object; span=(82, 83), match='1'>
# <re.Match object; span=(84, 85), match='1'>
# <re.Match object; span=(85, 86), match='2'>
# <re.Match object; span=(86, 87), match='3'>
# <re.Match object; span=(87, 88), match='1'>
# <re.Match object; span=(88, 89), match='4'>
# <re.Match object; span=(89, 90), match='0'>
# <re.Match object; span=(90, 91), match='9'>
# <re.Match object; span=(91, 92), match='0'>
# <re.Match object; span=(92, 93), match='1'>
# <re.Match object; span=(93, 94), match='2'>
# <re.Match object; span=(95, 96), match='1'>
# <re.Match object; span=(96, 97), match='4'>
# <re.Match object; span=(97, 98), match='8'>
# <re.Match object; span=(98, 99), match='5'>
# <re.Match object; span=(99, 100), match='9'>
# <re.Match object; span=(100, 101), match='2'>
# <re.Match object; span=(101, 102), match='9'>
# <re.Match object; span=(102, 103), match='4'>
# <re.Match object; span=(103, 104), match='1'>
# <re.Match object; span=(104, 105), match='1'>

# %% [markdown]
# \d — digit character: [0-9]
#
# \D — non-digit character: [^0-9]
#
# \w — alphanumerical character: [a-zA-Z0-9_]
#
# \W — non-alphanumerical character: [^a-zA-Z0-9_]
#
# \s — white-space character: [\t\n\r\f\v]
#
# \S — non-white-space character: [^\t\n\r\f\v]
#
# . — Match any character
#
# a — Match 'a' (normal text)
#
# ab — Match 'a' followed by 'b' (normal text)
#
# [abc] — Character class. Match one character: either 'a' or 'b' or 'c'
#
# [^abc] — Character class. Match one character: anything except 'a' or 'b' or 'c'
#
# [a-z] — Character class. Match one character: anything between 'a' and 'z'
#
# ^ and $ — Matches beginning and end of line
#
# \A and \Z — Matches beginning and end of entire string

# %%
pattern2= re.compile(r'^Start') # looks for the word 'start' at the beg. of the sentence

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# %%
browser = webdriver.Firefox()

# %%
url2 = 'https://finance.yahoo.com/'
browser.get(url2)
print(f"Successfully visited: {browser.title} ")
# Out:
# Successfully visited: Dine privatlivsvalg

# %%
button = browser.find_element(By.NAME, 'agree')
button.click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Cell In[5], line 2
#       1 button = browser.find_element(By.NAME, 'agree')
# ----> 2 button.click()
#
# File ~/miniconda3/envs/test_env/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:114, in WebElement.click(self)
#     107 def click(self) -> None:
#     108     """Clicks the element.
#     109
#     110     Example:
#     111         element = driver.find_element(By.ID, "foo")
#     112         element.click()
#     113     """
# --> 114     self._execute(Command.CLICK_ELEMENT)
#
# File ~/miniconda3/envs/test_env/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:508, in WebElement._execute(self, command, params)
#     506     params = {}
#     507 params["id"] = self._id
# --> 508 return self._parent.execute(command, params)
#
# ...

# %%
headlines = browser.find_elements(By.CLASS_NAME, 'yf-1u32w3i')
print(f"Found {len(headlines)} headlines.")
# Print the first 5 headlines found
for i, headline in enumerate(headlines[:5]):
    print(f"{i+1}: {headline.text}")
# Out:
# Found 0 headlines.

# %%
headlines = browser.find_elements(By.CLASS_NAME, 'clamp')
print(f"Found {len(headlines)} headlines.")
# Print the first 5 headlines found
for i, headline in enumerate(headlines[:5]):
    print(f"{i+1}: {headline.text}")
# Out:
# Found 0 headlines.

# %%
headlines = browser.find_elements(By.CSS_SELECTOR, 'h3.tw-line-clamp-none')
print(f"Found {len(headlines)} headlines.")
# Print the first 5 headlines found
for i, headline in enumerate(headlines[:5]):
    print(f"{i+1}: {headline.text}")
# Out:
# Found 14 headlines.
# 1: Top Trump official attacks NY Fed over tariff study
# 2: Carvana stock sinks on profit miss, vague guidance
# 3: Oil surges as Ukraine-Russia talks collapse, Iran-US tensions rise
# 4: Zuckerberg set to testify in landmark social media suit
# 5: US stocks see worst start vs. global markets since 1995

# %%
headlines = browser.find_elements(By.TAG_NAME, 'h3')
print(f"Found {len(headlines)} headlines.")
# Print the first 5 headlines found
for i, headline in enumerate(headlines[:5]):
    print(f"{i+1}: {headline.text}")
# Out:
# Found 41 headlines.
# 1:
# 2:
# 3:
# 4:
# 5:

# %%
browser.quit()
